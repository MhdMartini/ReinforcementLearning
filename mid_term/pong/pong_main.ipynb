# %%
# %run pong_agent.ipynb
# %run pong_env.ipynb
from itertools import count
import matplotlib.pyplot as plt
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def normalize(s):
    s_norm = np.copy(s)
    s_norm[I_Y_BALL] = np.interp(s_norm[I_Y_BALL], (0, 2), (0, 1))
    s_norm[I_VX_BALL] = np.interp(s_norm[I_VX_BALL], (- V_BALL, V_BALL), (0, 1))
    s_norm[I_VY_BALL] = np.interp(s_norm[I_VY_BALL], (- V_BALL, V_BALL), (0, 1))
    return s_norm

# %%
def train(env, agent, n_episodes, vis=False):
    pg.init()
    steps_per_e = np.zeros(n_episodes)
    for episode in tqdm(range(n_episodes)):
        s = env.reset()
        agent.reset()
        s_norm = normalize(s)
        for t in count():
            a, policy = agent.choose_action(s_norm)
            sp, r, terminal = env.step(actions[a])
            sp_norm = normalize(sp)
            w, theta = agent.learn(s_norm, a, r, sp_norm, terminal, policy)
            print(s_norm)
            if terminal:
                break
            s = sp
            s_norm = sp_norm
        
            if vis:
                cont = env.render()
                if cont is False or terminal:
                    pg.quit()
                    vis = False

        steps_per_e[episode] = t

    return w, theta, steps_per_e

# %%
def play(env, agent, n_episodes=1):
    pg.init()
    for episode in range(n_episodes):
        s = env.reset()
        s_norm = normalize(s)
        for t in count():
            a, _ = agent.choose_action(s_norm)
            sp, r, terminal = env.step(actions[a])
            sp_norm = normalize(sp)
            if terminal:
                break
            s = s_norm
            sp = sp_norm

            cont = env.render()
            if cont is False or terminal:
                break
    pg.quit()

# %%
def load_weights(idx, chunk):
    post = f"{(idx + 1) * chunk}.npy"
    Q = np.load(f"Q_{post}")
    s_count = np.load(f"s_count_{post}")
    sa_count = np.load(f"sa_count_{post}")
    return Q, s_count, sa_count
    
def save_weights(dict_, idx, chunk):
    for name, val in dict_.items():
        np.save(f"{name}_{(idx + 1) * chunk}", val)

# %%
if __name__ == "__main__":
    degree = 3
    n_states = 5
    n_features = (degree + 1) ** n_states
    actions = [-2, 0, 2]
    n_actions = len(actions)

    alpha = 1e-4
    lambda_w = 0.5
    lambda_theta = 0.5
    gamma = 0.99

    offset = 0
    n_episodes = 150
    try:
        w = np.load(f"w_{offset}.npy")
        theta = np.load(f"theta_{offset}.npy")
        print("Imported Weights!")
    except FileNotFoundError:
        w, theta = np.zeros(n_features), np.zeros(n_actions * n_features)

# %%
agent = ActorCriticETAgent(n_features, degree, n_states, n_actions, alpha, gamma, lambda_theta, lambda_w)
env = PongSoloEnv(n_states, actions)
w, theta, steps_per_e = train(env, agent, n_episodes, vis=False)
np.save(f"w_{n_episodes + offset}", w)
np.save(f"theta_{n_episodes + offset}", theta)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# [0.66978695 0.93908353 0.5        0.5921061  0.00855675]
# [0.66978695 0.94829414 0.47542784 0.5921061  0.00855675]
# [0.68978695 0.95750475 0.45085568 0.5921061  0.00855675]
# [0.66978695 0.96671536 0.42628351 0.5921061  0.00855675]
# [0.64978695 0.97592597 0.40171135 0.5921061  0.00855675]
# [0.64978695 0.98       0.37713919 0.40789493 0.00855675]
# [0.64978695 0.97078949 0.35256703 0.40789493 0.00855675]
# [0.66978695 0.96157899 0.32799486 0.40789493 0.00855675]
# [0.66978695 0.95236848 0.3034227  0.40789493 0.00855675]
# [0.66978695 0.94315797 0.27885054 0.40789493 0.00855675]
# [0.64978695 0.93394746 0.25427838 0.40789493 0.00855675]
# [0.66978695 0.92473696 0.22970621 0.40789493 0.00855675]
# [0.64978695 0.91552645 0.20513405 0.40789493 0.00855675]
# [0.62978695 0.90631594 0.18056189 0.40789493 0.00855675]
# [0.60978695 0.89710543 0.15598973 0.40789493 0.00855675]
#   1%|          | 1/150 [00:00<02:13,  1.12it/s]
# [0.58978695 0.88789493 0.13141756 0.40789493 0.00855675]
# [0.60978695 0.87868442 0.1068454  0.40789493 0.00855675]
# [0.58978695 0.86947391 0.08227324 0.40789493 0.00855675]
# [0.15755523 0.27089796 0.5        0.73974053 0.93877611]
# [0.15755523 0.29487201 0.52193881 0.73974053 0.93877611]
# [0.17755523 0.31884606 0.54387761 0.73974053 0.93877611]
# [0.19755523 0.34282011 0.56581642 0.73974053 0.93877611]
# [0.19755523 0.36679417 0.58775522 0.73974053 0.93877611]
# [0.21755523 0.39076822 0.60969403 0.73974053 0.93877611]
# [0.23755523 0.41474227 0.63163283 0.73974053 0.93877611]
# [0.21755523 0.43871633 0.65357164 0.73974053 0.93877611]
# [0.21755523 0.46269038 0.67551045 0.73974053 0.93877611]
# [0.23755523 0.48666443 0.69744925 0.73974053 0.93877611]
# [0.25755523 0.51063849 0.71938806 0.73974053 0.93877611]
# [0.23755523 0.53461254 0.74132686 0.73974053 0.93877611]
# [0.21755523 0.55858659 0.76326567 0.73974053 0.93877611]
# [0.19755523 0.58256065 0.78520447 0.73974053 0.93877611]
# [0.17755523 0.6065347  0.80714328 0.73974053 0.93877611]
# [0.15755523 0.63050875 0.82908209 0.73974053 0.93877611]
# [0.17755523 0.6544828  0.85102089 0.73974053 0.93877611]
# [0.15755523 0.67845686 0.8729597  0.73974053 0.93877611]
# [0.15755523 0.70243091 0.8948985  0.73974053 0.93877611]
# [0.13755523 0.72640496 0.91683731 0.73974053 0.93877611]
# [0.15755523 0.75037902 0.93877611 0.73974053 0.93877611]
# [0.17755523 0.77435307 0.96071492 0.73974053 0.93877611]
# [0.17755523 0.79832712 0.98265372 0.73974053 0.93877611]
# [0.15755523 0.82230118 0.99       0.73974053 0.06122389]
# [0.13755523 0.84627523 0.96806119 0.73974053 0.06122389]
# [0.11755523 0.87024928 0.94612239 0.73974053 0.06122389]
# [0.11755523 0.89422334 0.92418358 0.73974053 0.06122389]
# [0.11755523 0.91819739 0.90224478 0.73974053 0.06122389]
# [0.13755523 0.94217144 0.88030597 0.73974053 0.06122389]
# [0.11755523 0.96614549 0.85836717 0.73974053 0.06122389]
# [0.11755523 0.98       0.83642836 0.26075085 0.06122389]
# [0.13755523 0.95607508 0.81448955 0.26075085 0.06122389]
# [0.11755523 0.93215017 0.79255075 0.26075085 0.06122389]
# [0.1        0.90822525 0.77061194 0.26075085 0.06122389]
# [0.1        0.88430034 0.74867314 0.26075085 0.06122389]
# [0.12       0.86037542 0.72673433 0.26075085 0.06122389]
# [0.14       0.83645051 0.70479553 0.26075085 0.06122389]
# [0.14       0.81252559 0.68285672 0.26075085 0.06122389]
# [0.16       0.78860068 0.66091791 0.26075085 0.06122389]
# [0.18       0.76467576 0.63897911 0.26075085 0.06122389]
# [0.16       0.74075085 0.6170403  0.26075085 0.06122389]
# [0.16       0.71682593 0.5951015  0.26075085 0.06122389]
# [0.14       0.69290102 0.57316269 0.26075085 0.06122389]
# [0.14       0.6689761  0.55122389 0.26075085 0.06122389]
# [0.12       0.64505119 0.52928508 0.26075085 0.06122389]
# [0.14       0.62112627 0.50734628 0.26075085 0.06122389]
# [0.12       0.59720136 0.48540747 0.26075085 0.06122389]
# [0.1        0.57327644 0.46346866 0.26075085 0.06122389]
# [0.1        0.54935153 0.44152986 0.26075085 0.06122389]
# [0.1        0.52542661 0.41959105 0.26075085 0.06122389]
# [0.1        0.5015017  0.39765225 0.26075085 0.06122389]
# [0.1        0.47757678 0.37571344 0.26075085 0.06122389]
# [0.1        0.45365187 0.35377464 0.26075085 0.06122389]
# [0.1        0.42972695 0.33183583 0.26075085 0.06122389]
# [0.12       0.40580204 0.30989702 0.26075085 0.06122389]
# [0.12       0.38187712 0.28795822 0.26075085 0.06122389]
# [0.14       0.3579522  0.26601941 0.26075085 0.06122389]
# [0.14       0.33402729 0.24408061 0.26075085 0.06122389]
# [0.14       0.31010237 0.2221418  0.26075085 0.06122389]
# [0.14       0.28617746 0.200203   0.26075085 0.06122389]
# [0.14       0.26225254 0.17826419 0.26075085 0.06122389]
# [0.14       0.23832763 0.15632538 0.26075085 0.06122389]
# [0.12       0.21440271 0.13438658 0.26075085 0.06122389]
# [0.14       0.1904778  0.11244777 0.26075085 0.06122389]
# [0.14       0.16655288 0.09050897 0.26075085 0.06122389]
# [0.16       0.14262797 0.0725     0.46075085 0.93877611]
# [0.14       0.13870305 0.09443881 0.46075085 0.93877611]
# [0.14       0.13477814 0.11637761 0.46075085 0.93877611]
# [0.14       0.13085322 0.13831642 0.46075085 0.93877611]
# [0.14       0.12692831 0.16025522 0.46075085 0.93877611]
# [0.14       0.12300339 0.18219403 0.46075085 0.93877611]
# [0.12       0.11907848 0.20413283 0.46075085 0.93877611]
# [0.12       0.11515356 0.22607164 0.46075085 0.93877611]
# [0.1        0.11122865 0.24801045 0.46075085 0.93877611]
# [0.12       0.10730373 0.26994925 0.46075085 0.93877611]
# [0.12       0.10337882 0.29188806 0.46075085 0.93877611]
# [0.12       0.0994539  0.31382686 0.46075085 0.93877611]
# [0.12       0.09552899 0.33576567 0.46075085 0.93877611]
# [0.1        0.09160407 0.35770447 0.46075085 0.93877611]
# [0.1        0.08767915 0.37964328 0.46075085 0.93877611]
# [0.1        0.08375424 0.40158209 0.46075085 0.93877611]
# [0.1        0.07982932 0.42352089 0.46075085 0.93877611]
# [0.12       0.07590441 0.4454597  0.46075085 0.93877611]
# [0.12       0.07197949 0.4673985  0.46075085 0.93877611]
# [0.1        0.06805458 0.48933731 0.46075085 0.93877611]
# [0.1        0.06412966 0.51127611 0.46075085 0.93877611]
# [0.1        0.06020475 0.53321492 0.46075085 0.93877611]
# [0.12       0.05627983 0.55515372 0.46075085 0.93877611]
# [0.1        0.05235492 0.57709253 0.46075085 0.93877611]
# [0.12       0.04843    0.59903134 0.46075085 0.93877611]
# [0.14       0.04450509 0.62097014 0.46075085 0.93877611]
# [0.16       0.04058017 0.64290895 0.46075085 0.93877611]
# [0.18       0.03665526 0.66484775 0.46075085 0.93877611]
# [0.2        0.03273034 0.68678656 0.46075085 0.93877611]
# [0.22       0.02880543 0.70872536 0.46075085 0.93877611]
# [0.24       0.02488051 0.73066417 0.46075085 0.93877611]
# [0.24       0.0209556  0.75260298 0.46075085 0.93877611]
# [0.22       0.02       0.77454178 0.53876742 0.93877611]
# [0.24       0.02387674 0.79648059 0.53876742 0.93877611]
# [0.24       0.02775348 0.81841939 0.53876742 0.93877611]
# [0.22       0.03163023 0.8403582  0.53876742 0.93877611]
# [0.22       0.03550697 0.862297   0.53876742 0.93877611]
# [0.22       0.03938371 0.88423581 0.53876742 0.93877611]
# [0.24       0.04326045 0.90617462 0.53876742 0.93877611]
# [0.24       0.0471372  0.92811342 0.53876742 0.93877611]
# [0.26       0.05101394 0.95005223 0.53876742 0.93877611]
# [0.28       0.05489068 0.97199103 0.53876742 0.93877611]
# [0.28       0.05876742 0.99       0.53876742 0.06122389]
# [0.26       0.06264416 0.96806119 0.53876742 0.06122389]
# [0.28       0.06652091 0.94612239 0.53876742 0.06122389]
# [0.28       0.07039765 0.92418358 0.53876742 0.06122389]
# [0.28       0.07427439 0.90224478 0.53876742 0.06122389]
# [0.28       0.07815113 0.88030597 0.53876742 0.06122389]
# [0.28       0.08202787 0.85836717 0.53876742 0.06122389]
# [0.3        0.08590462 0.83642836 0.53876742 0.06122389]
# [0.32       0.08978136 0.81448955 0.53876742 0.06122389]
# [0.34       0.0936581  0.79255075 0.53876742 0.06122389]
# [0.34       0.09753484 0.77061194 0.53876742 0.06122389]
# [0.32       0.10141159 0.74867314 0.53876742 0.06122389]
# [0.34       0.10528833 0.72673433 0.53876742 0.06122389]
# [0.32       0.10916507 0.70479553 0.53876742 0.06122389]
# [0.32       0.11304181 0.68285672 0.53876742 0.06122389]
# [0.34       0.11691855 0.66091791 0.53876742 0.06122389]
# [0.34       0.1207953  0.63897911 0.53876742 0.06122389]
# [0.34       0.12467204 0.6170403  0.53876742 0.06122389]
# [0.32       0.12854878 0.5951015  0.53876742 0.06122389]
# [0.32       0.13242552 0.57316269 0.53876742 0.06122389]
# [0.34       0.13630227 0.55122389 0.53876742 0.06122389]
# [0.32       0.14017901 0.52928508 0.53876742 0.06122389]
# [0.3        0.14405575 0.50734628 0.53876742 0.06122389]
# [0.3        0.14793249 0.48540747 0.53876742 0.06122389]
# [0.28       0.15180923 0.46346866 0.53876742 0.06122389]
# [0.26       0.15568598 0.44152986 0.53876742 0.06122389]
# [0.24       0.15956272 0.41959105 0.53876742 0.06122389]
# [0.22       0.16343946 0.39765225 0.53876742 0.06122389]
# [0.2        0.1673162  0.37571344 0.53876742 0.06122389]
# [0.18       0.17119295 0.35377464 0.53876742 0.06122389]
# [0.18       0.17506969 0.33183583 0.53876742 0.06122389]
# [0.16       0.17894643 0.30989702 0.53876742 0.06122389]
# [0.14       0.18282317 0.28795822 0.53876742 0.06122389]
# [0.16       0.18669991 0.26601941 0.53876742 0.06122389]
# [0.16       0.19057666 0.24408061 0.53876742 0.06122389]
# [0.16       0.1944534  0.2221418  0.53876742 0.06122389]
# [0.16       0.19833014 0.200203   0.53876742 0.06122389]
# [0.16       0.20220688 0.17826419 0.53876742 0.06122389]
# [0.18       0.20608362 0.15632538 0.53876742 0.06122389]
# [0.2        0.20996037 0.13438658 0.53876742 0.06122389]
# [0.18       0.21383711 0.11244777 0.53876742 0.06122389]
# [0.18       0.21771385 0.09050897 0.53876742 0.06122389]
# [0.2        0.22159059 0.0725     0.73876742 0.93877611]
# [0.18       0.24546734 0.09443881 0.73876742 0.93877611]
# [0.18       0.26934408 0.11637761 0.73876742 0.93877611]
# [0.18       0.29322082 0.13831642 0.73876742 0.93877611]
# [0.18       0.31709756 0.16025522 0.73876742 0.93877611]
#   1%|          | 1/150 [00:08<22:04,  8.89s/it]
# [0.18       0.3409743  0.18219403 0.73876742 0.93877611]
# [0.2        0.36485105 0.20413283 0.73876742 0.93877611]
# [0.18       0.38872779 0.22607164 0.73876742 0.93877611]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2b18563a8948> in <module>
#       1 env = PongSoloEnv(n_states, actions)
# ----> 2 w, theta, steps_per_e = train(env, agent, n_episodes, vis=False)
#       3 np.save(f"w_{n_episodes + offset}", w)
#       4 np.save(f"theta_{n_episodes + offset}", theta)
#
# <ipython-input-3-b6a322441405> in train(env, agent, n_episodes, vis)
#      10             sp, r, terminal = env.step(actions[a])
#      11             sp_norm = normalize(sp)
# ---> 12             w, theta = agent.learn(s_norm, a, r, sp_norm, terminal, policy)
#      13             print(s_norm)
#      14             if terminal:
#
# <ipython-input-1-0bbf6d92e3cf> in learn(self, s, a, r, sp, terminal, policy)
#      28
#      29         # calc error
# ---> 30         delta = r + self.gamma * v_sp  - self.v_s(s)
#      31
#      32         # update z_w
#
# <ipython-input-1-0bbf6d92e3cf> in v_s(self, s)
#      83     def v_s(self, s):
#      84         """return the value of a state given the weights vector"""
# ---> 85         return self.w @ self.x_s(s)
#      86
#      87     def get_pi_gradient(self, s, a, policy):
#
# <ipython-input-1-0bbf6d92e3cf> in x_s(self, s)
#      78         for i, c in enumerate(product(range(self.degree + 1), repeat=self.n_states)):
#      79             c = np.array(c)
# ---> 80             x[i] = np.cos(np.pi * s.T @ c)
#      81         return x
#      82
#
# KeyboardInterrupt:

# %%
# plt.plot(steps_per_e)

# %%
# env = PongSoloEnv(n_states, actions)
# play(env, agent, n_episodes=10)
